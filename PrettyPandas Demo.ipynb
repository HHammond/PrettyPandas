# %%
from PrettyPandas import PrettyPandas

# %%
import pandas as pd
import numpy as np

np.random.seed(24)
df = pd.DataFrame({'A': np.linspace(1, 10, 10)})
df = pd.concat([df, pd.DataFrame(np.random.randn(10, 4), columns=list('BCDE'))],
               axis=1)

# %%
df
# Out:
#     A         B         C         D         E
# 0   1  1.329212 -0.770033 -0.316280 -0.990810
# 1   2 -1.070816 -1.438713  0.564417  0.295722
# 2   3 -1.626404  0.219565  0.678805  1.889273
# 3   4  0.961538  0.104011 -0.481165  0.850229
# 4   5  1.453425  1.057737  0.165562  0.515018
# 5   6 -1.336936  0.562861  1.392855 -0.063328
# 6   7  0.121668  1.207603 -0.002040  1.627796
# 7   8  0.354493  1.037528 -0.385684  0.519818
# 8   9  1.686583 -1.325963  1.428984 -2.089354
# 9  10 -0.129820  0.631523 -0.586538  0.290720

# %% [markdown]
# ## Summaries

# %% [markdown]
# Supported summaries:
#
# * total
# * average
# * min
# * max
# * median

# %%
PrettyPandas(df)
# Out:
#         <style  type="text/css" >
#
#             #T_cb0cd6b3_bc78_11e5_b9a8_80e65010311a th {
#
#                 background: #eee;
#
#                 font-weight: 500;
#
#             }
#
#             #T_cb0cd6b3_bc78_11e5_b9a8_80e65010311a td {
#
#                 text-align: right;
#
#                 min-width: 3em;
#
#             }
#
#             #T_cb0cd6b3_bc78_11e5_b9a8_80e65010311a * {
#
#                 border-color: #c0c0c0;
#
#             }
#
#
#         </style>
#
#         <table id="T_cb0cd6b3_bc78_11e5_b9a8_80e65010311a" None>
#
#
#         <thead>
#
#             <tr>
#
#                 <th class="blank">
#
#                 <th class="col_heading level0 col0">A
#
#                 <th class="col_heading level0 col1">B
#
#                 <th class="col_heading level0 col2">C
#
#                 <th class="col_heading level0 col3">D
#
#                 <th class="col_heading level0 col4">E
#
#             </tr>
#
#         </thead>
#         <tbody>
#
#             <tr>
#
#                 <th id="T_cb0cd6b3_bc78_11e5_b9a8_80e65010311a" class="row_heading level4 row0">
#
#                         0.0
#
#
#                 <td id="T_cb0cd6b3_bc78_11e5_b9a8_80e65010311arow0_col0" class="data row0 col0">
#
#                         1.0
#
#
#                 <td id="T_cb0cd6b3_bc78_11e5_b9a8_80e65010311arow0_col1" class="data row0 col1">
#
#                         1.329212
#
#
#                 <td id="T_cb0cd6b3_bc78_11e5_b9a8_80e65010311arow0_col2" class="data row0 col2">
#
#                         -0.770033
#
#
#                 <td id="T_cb0cd6b3_bc78_11e5_b9a8_80e65010311arow0_col3" class="data row0 col3">
#
#                         -0.31628
#
#
#                 <td id="T_cb0cd6b3_bc78_11e5_b9a8_80e65010311arow0_col4" class="data row0 col4">
#
#                         -0.99081
#
#
#             </tr>
#
#             <tr>
#
#                 <th id="T_cb0cd6b3_bc78_11e5_b9a8_80e65010311a" class="row_heading level4 row1">
#
#                         1.0
#
#
#                 <td id="T_cb0cd6b3_bc78_11e5_b9a8_80e65010311arow1_col0" class="data row1 col0">
#
#                         2.0
#
#
#                 <td id="T_cb0cd6b3_bc78_11e5_b9a8_80e65010311arow1_col1" class="data row1 col1">
#
#                         -1.070816
#
#
#                 <td id="T_cb0cd6b3_bc78_11e5_b9a8_80e65010311arow1_col2" class="data row1 col2">
#
#                         -1.438713
#
#
#                 <td id="T_cb0cd6b3_bc78_11e5_b9a8_80e65010311arow1_col3" class="data row1 col3">
#
#                         0.564417
#
#
#                 <td id="T_cb0cd6b3_bc78_11e5_b9a8_80e65010311arow1_col4" class="data row1 col4">
#
#                         0.295722
#
#
#             </tr>
#
#             <tr>
#
#                 <th id="T_cb0cd6b3_bc78_11e5_b9a8_80e65010311a" class="row_heading level4 row2">
#
#                         2.0
#
#
#                 <td id="T_cb0cd6b3_bc78_11e5_b9a8_80e65010311arow2_col0" class="data row2 col0">
#
#                         3.0
#
#
#                 <td id="T_cb0cd6b3_bc78_11e5_b9a8_80e65010311arow2_col1" class="data row2 col1">
#
#                         -1.626404
#
#
#                 <td id="T_cb0cd6b3_bc78_11e5_b9a8_80e65010311arow2_col2" class="data row2 col2">
#
#                         0.219565
#
#
#                 <td id="T_cb0cd6b3_bc78_11e5_b9a8_80e65010311arow2_col3" class="data row2 col3">
#
#                         0.678805
#
#
#                 <td id="T_cb0cd6b3_bc78_11e5_b9a8_80e65010311arow2_col4" class="data row2 col4">
#
#                         1.889273
#
#
#             </tr>
#
#             <tr>
#
#                 <th id="T_cb0cd6b3_bc78_11e5_b9a8_80e65010311a" class="row_heading level4 row3">
#
#                         3.0
#
#
#                 <td id="T_cb0cd6b3_bc78_11e5_b9a8_80e65010311arow3_col0" class="data row3 col0">
#
#                         4.0
#
#
#                 <td id="T_cb0cd6b3_bc78_11e5_b9a8_80e65010311arow3_col1" class="data row3 col1">
#
#                         0.961538
#
#
#                 <td id="T_cb0cd6b3_bc78_11e5_b9a8_80e65010311arow3_col2" class="data row3 col2">
#
#                         0.104011
#
#
#                 <td id="T_cb0cd6b3_bc78_11e5_b9a8_80e65010311arow3_col3" class="data row3 col3">
#
#                         -0.481165
#
#
#                 <td id="T_cb0cd6b3_bc78_11e5_b9a8_80e65010311arow3_col4" class="data row3 col4">
#
#                         0.850229
#
#
#             </tr>
#
#             <tr>
#
#                 <th id="T_cb0cd6b3_bc78_11e5_b9a8_80e65010311a" class="row_heading level4 row4">
#
#                         4.0
#
#
#                 <td id="T_cb0cd6b3_bc78_11e5_b9a8_80e65010311arow4_col0" class="data row4 col0">
#
#                         5.0
#
#
#                 <td id="T_cb0cd6b3_bc78_11e5_b9a8_80e65010311arow4_col1" class="data row4 col1">
#
#                         1.453425
#
#
#                 <td id="T_cb0cd6b3_bc78_11e5_b9a8_80e65010311arow4_col2" class="data row4 col2">
#
#                         1.057737
#
#
#                 <td id="T_cb0cd6b3_bc78_11e5_b9a8_80e65010311arow4_col3" class="data row4 col3">
#
#                         0.165562
#
#
#                 <td id="T_cb0cd6b3_bc78_11e5_b9a8_80e65010311arow4_col4" class="data row4 col4">
#
#                         0.515018
#
#
#             </tr>
#
#             <tr>
#
#                 <th id="T_cb0cd6b3_bc78_11e5_b9a8_80e65010311a" class="row_heading level4 row5">
#
#                         5.0
#
#
#                 <td id="T_cb0cd6b3_bc78_11e5_b9a8_80e65010311arow5_col0" class="data row5 col0">
#
#                         6.0
#
#
#                 <td id="T_cb0cd6b3_bc78_11e5_b9a8_80e65010311arow5_col1" class="data row5 col1">
#
#                         -1.336936
#
#
#                 <td id="T_cb0cd6b3_bc78_11e5_b9a8_80e65010311arow5_col2" class="data row5 col2">
#
#                         0.562861
#
#
#                 <td id="T_cb0cd6b3_bc78_11e5_b9a8_80e650103

# %%
PrettyPandas(df).total()
# Out:
#         <style  type="text/css" >
#
#             #T_cb12784c_bc78_11e5_ab7f_80e65010311a th {
#
#                 background: #eee;
#
#                 font-weight: 500;
#
#             }
#
#             #T_cb12784c_bc78_11e5_ab7f_80e65010311a td {
#
#                 text-align: right;
#
#                 min-width: 3em;
#
#             }
#
#             #T_cb12784c_bc78_11e5_ab7f_80e65010311a * {
#
#                 border-color: #c0c0c0;
#
#             }
#
#             #T_cb12784c_bc78_11e5_ab7f_80e65010311a tr:nth-child(11) {
#
#                 background: #eee;
#
#                 font-weight: 500;
#
#             }
#
#
#         </style>
#
#         <table id="T_cb12784c_bc78_11e5_ab7f_80e65010311a" None>
#
#
#         <thead>
#
#             <tr>
#
#                 <th class="blank">
#
#                 <th class="col_heading level0 col0">A
#
#                 <th class="col_heading level0 col1">B
#
#                 <th class="col_heading level0 col2">C
#
#                 <th class="col_heading level0 col3">D
#
#                 <th class="col_heading level0 col4">E
#
#             </tr>
#
#         </thead>
#         <tbody>
#
#             <tr>
#
#                 <th id="T_cb12784c_bc78_11e5_ab7f_80e65010311a" class="row_heading level4 row0">
#
#                         0.0
#
#
#                 <td id="T_cb12784c_bc78_11e5_ab7f_80e65010311arow0_col0" class="data row0 col0">
#
#                         1.0
#
#
#                 <td id="T_cb12784c_bc78_11e5_ab7f_80e65010311arow0_col1" class="data row0 col1">
#
#                         1.329212
#
#
#                 <td id="T_cb12784c_bc78_11e5_ab7f_80e65010311arow0_col2" class="data row0 col2">
#
#                         -0.770033
#
#
#                 <td id="T_cb12784c_bc78_11e5_ab7f_80e65010311arow0_col3" class="data row0 col3">
#
#                         -0.31628
#
#
#                 <td id="T_cb12784c_bc78_11e5_ab7f_80e65010311arow0_col4" class="data row0 col4">
#
#                         -0.99081
#
#
#             </tr>
#
#             <tr>
#
#                 <th id="T_cb12784c_bc78_11e5_ab7f_80e65010311a" class="row_heading level4 row1">
#
#                         1.0
#
#
#                 <td id="T_cb12784c_bc78_11e5_ab7f_80e65010311arow1_col0" class="data row1 col0">
#
#                         2.0
#
#
#                 <td id="T_cb12784c_bc78_11e5_ab7f_80e65010311arow1_col1" class="data row1 col1">
#
#                         -1.070816
#
#
#                 <td id="T_cb12784c_bc78_11e5_ab7f_80e65010311arow1_col2" class="data row1 col2">
#
#                         -1.438713
#
#
#                 <td id="T_cb12784c_bc78_11e5_ab7f_80e65010311arow1_col3" class="data row1 col3">
#
#                         0.564417
#
#
#                 <td id="T_cb12784c_bc78_11e5_ab7f_80e65010311arow1_col4" class="data row1 col4">
#
#                         0.295722
#
#
#             </tr>
#
#             <tr>
#
#                 <th id="T_cb12784c_bc78_11e5_ab7f_80e65010311a" class="row_heading level4 row2">
#
#                         2.0
#
#
#                 <td id="T_cb12784c_bc78_11e5_ab7f_80e65010311arow2_col0" class="data row2 col0">
#
#                         3.0
#
#
#                 <td id="T_cb12784c_bc78_11e5_ab7f_80e65010311arow2_col1" class="data row2 col1">
#
#                         -1.626404
#
#
#                 <td id="T_cb12784c_bc78_11e5_ab7f_80e65010311arow2_col2" class="data row2 col2">
#
#                         0.219565
#
#
#                 <td id="T_cb12784c_bc78_11e5_ab7f_80e65010311arow2_col3" class="data row2 col3">
#
#                         0.678805
#
#
#                 <td id="T_cb12784c_bc78_11e5_ab7f_80e65010311arow2_col4" class="data row2 col4">
#
#                         1.889273
#
#
#             </tr>
#
#             <tr>
#
#                 <th id="T_cb12784c_bc78_11e5_ab7f_80e65010311a" class="row_heading level4 row3">
#
#                         3.0
#
#
#                 <td id="T_cb12784c_bc78_11e5_ab7f_80e65010311arow3_col0" class="data row3 col0">
#
#                         4.0
#
#
#                 <td id="T_cb12784c_bc78_11e5_ab7f_80e65010311arow3_col1" class="data row3 col1">
#
#                         0.961538
#
#
#                 <td id="T_cb12784c_bc78_11e5_ab7f_80e65010311arow3_col2" class="data row3 col2">
#
#                         0.104011
#
#
#                 <td id="T_cb12784c_bc78_11e5_ab7f_80e65010311arow3_col3" class="data row3 col3">
#
#                         -0.481165
#
#
#                 <td id="T_cb12784c_bc78_11e5_ab7f_80e65010311arow3_col4" class="data row3 col4">
#
#                         0.850229
#
#
#             </tr>
#
#             <tr>
#
#                 <th id="T_cb12784c_bc78_11e5_ab7f_80e65010311a" class="row_heading level4 row4">
#
#                         4.0
#
#
#                 <td id="T_cb12784c_bc78_11e5_ab7f_80e65010311arow4_col0" class="data row4 col0">
#
#                         5.0
#
#
#                 <td id="T_cb12784c_bc78_11e5_ab7f_80e65010311arow4_col1" class="data row4 col1">
#
#                         1.453425
#
#
#                 <td id="T_cb12784c_bc78_11e5_ab7f_80e65010311arow4_col2" class="data row4 col2">
#
#                         1.057737
#
#
#                 <td id="T_cb12784c_bc78_11e5_ab7f_80e65010311arow4_col3" class="data row4 col3">
#
#                         0.165562
#
#
#                 <td id="T_cb12784c_bc78_11e5_ab7f_80e65010311arow4_col4" class="data row4 col4">
#
#                         0.515018
#
#
#             </tr>
#
#             <tr>
#
#                 <th id="T_cb12784c_bc78_11e5_ab7f_80e65010311a" class="row_heading level4 row5">
#
#                         5.0
#
#
#                 <td id="T_cb12784c_bc78_11e5_ab7f_80e65010311arow5_col0" class="data row5 col0">
#
#                         6.0
#
#
#                 <td id="T_cb12784c_bc78_11e5_ab7f_80e65010311arow5_col1" class="data row5 col1">
#
#                         -1.336936
#
#
#                 <td id="T_cb12784c_bc78_11e5_ab

# %%
PrettyPandas(df).average()
# Out:
#         <style  type="text/css" >
#
#             #T_cb163e00_bc78_11e5_9596_80e65010311a th {
#
#                 background: #eee;
#
#                 font-weight: 500;
#
#             }
#
#             #T_cb163e00_bc78_11e5_9596_80e65010311a td {
#
#                 text-align: right;
#
#                 min-width: 3em;
#
#             }
#
#             #T_cb163e00_bc78_11e5_9596_80e65010311a * {
#
#                 border-color: #c0c0c0;
#
#             }
#
#             #T_cb163e00_bc78_11e5_9596_80e65010311a tr:nth-child(11) {
#
#                 background: #eee;
#
#                 font-weight: 500;
#
#             }
#
#
#         </style>
#
#         <table id="T_cb163e00_bc78_11e5_9596_80e65010311a" None>
#
#
#         <thead>
#
#             <tr>
#
#                 <th class="blank">
#
#                 <th class="col_heading level0 col0">A
#
#                 <th class="col_heading level0 col1">B
#
#                 <th class="col_heading level0 col2">C
#
#                 <th class="col_heading level0 col3">D
#
#                 <th class="col_heading level0 col4">E
#
#             </tr>
#
#         </thead>
#         <tbody>
#
#             <tr>
#
#                 <th id="T_cb163e00_bc78_11e5_9596_80e65010311a" class="row_heading level4 row0">
#
#                         0.0
#
#
#                 <td id="T_cb163e00_bc78_11e5_9596_80e65010311arow0_col0" class="data row0 col0">
#
#                         1.0
#
#
#                 <td id="T_cb163e00_bc78_11e5_9596_80e65010311arow0_col1" class="data row0 col1">
#
#                         1.329212
#
#
#                 <td id="T_cb163e00_bc78_11e5_9596_80e65010311arow0_col2" class="data row0 col2">
#
#                         -0.770033
#
#
#                 <td id="T_cb163e00_bc78_11e5_9596_80e65010311arow0_col3" class="data row0 col3">
#
#                         -0.31628
#
#
#                 <td id="T_cb163e00_bc78_11e5_9596_80e65010311arow0_col4" class="data row0 col4">
#
#                         -0.99081
#
#
#             </tr>
#
#             <tr>
#
#                 <th id="T_cb163e00_bc78_11e5_9596_80e65010311a" class="row_heading level4 row1">
#
#                         1.0
#
#
#                 <td id="T_cb163e00_bc78_11e5_9596_80e65010311arow1_col0" class="data row1 col0">
#
#                         2.0
#
#
#                 <td id="T_cb163e00_bc78_11e5_9596_80e65010311arow1_col1" class="data row1 col1">
#
#                         -1.070816
#
#
#                 <td id="T_cb163e00_bc78_11e5_9596_80e65010311arow1_col2" class="data row1 col2">
#
#                         -1.438713
#
#
#                 <td id="T_cb163e00_bc78_11e5_9596_80e65010311arow1_col3" class="data row1 col3">
#
#                         0.564417
#
#
#                 <td id="T_cb163e00_bc78_11e5_9596_80e65010311arow1_col4" class="data row1 col4">
#
#                         0.295722
#
#
#             </tr>
#
#             <tr>
#
#                 <th id="T_cb163e00_bc78_11e5_9596_80e65010311a" class="row_heading level4 row2">
#
#                         2.0
#
#
#                 <td id="T_cb163e00_bc78_11e5_9596_80e65010311arow2_col0" class="data row2 col0">
#
#                         3.0
#
#
#                 <td id="T_cb163e00_bc78_11e5_9596_80e65010311arow2_col1" class="data row2 col1">
#
#                         -1.626404
#
#
#                 <td id="T_cb163e00_bc78_11e5_9596_80e65010311arow2_col2" class="data row2 col2">
#
#                         0.219565
#
#
#                 <td id="T_cb163e00_bc78_11e5_9596_80e65010311arow2_col3" class="data row2 col3">
#
#                         0.678805
#
#
#                 <td id="T_cb163e00_bc78_11e5_9596_80e65010311arow2_col4" class="data row2 col4">
#
#                         1.889273
#
#
#             </tr>
#
#             <tr>
#
#                 <th id="T_cb163e00_bc78_11e5_9596_80e65010311a" class="row_heading level4 row3">
#
#                         3.0
#
#
#                 <td id="T_cb163e00_bc78_11e5_9596_80e65010311arow3_col0" class="data row3 col0">
#
#                         4.0
#
#
#                 <td id="T_cb163e00_bc78_11e5_9596_80e65010311arow3_col1" class="data row3 col1">
#
#                         0.961538
#
#
#                 <td id="T_cb163e00_bc78_11e5_9596_80e65010311arow3_col2" class="data row3 col2">
#
#                         0.104011
#
#
#                 <td id="T_cb163e00_bc78_11e5_9596_80e65010311arow3_col3" class="data row3 col3">
#
#                         -0.481165
#
#
#                 <td id="T_cb163e00_bc78_11e5_9596_80e65010311arow3_col4" class="data row3 col4">
#
#                         0.850229
#
#
#             </tr>
#
#             <tr>
#
#                 <th id="T_cb163e00_bc78_11e5_9596_80e65010311a" class="row_heading level4 row4">
#
#                         4.0
#
#
#                 <td id="T_cb163e00_bc78_11e5_9596_80e65010311arow4_col0" class="data row4 col0">
#
#                         5.0
#
#
#                 <td id="T_cb163e00_bc78_11e5_9596_80e65010311arow4_col1" class="data row4 col1">
#
#                         1.453425
#
#
#                 <td id="T_cb163e00_bc78_11e5_9596_80e65010311arow4_col2" class="data row4 col2">
#
#                         1.057737
#
#
#                 <td id="T_cb163e00_bc78_11e5_9596_80e65010311arow4_col3" class="data row4 col3">
#
#                         0.165562
#
#
#                 <td id="T_cb163e00_bc78_11e5_9596_80e65010311arow4_col4" class="data row4 col4">
#
#                         0.515018
#
#
#             </tr>
#
#             <tr>
#
#                 <th id="T_cb163e00_bc78_11e5_9596_80e65010311a" class="row_heading level4 row5">
#
#                         5.0
#
#
#                 <td id="T_cb163e00_bc78_11e5_9596_80e65010311arow5_col0" class="data row5 col0">
#
#                         6.0
#
#
#                 <td id="T_cb163e00_bc78_11e5_9596_80e65010311arow5_col1" class="data row5 col1">
#
#                         -1.336936
#
#
#                 <td id="T_cb163e00_bc78_11e5_95

# %%
PrettyPandas(df).average(axis=1)
# Out:
#         <style  type="text/css" >
#
#             #T_cb199366_bc78_11e5_affb_80e65010311a th {
#
#                 background: #eee;
#
#                 font-weight: 500;
#
#             }
#
#             #T_cb199366_bc78_11e5_affb_80e65010311a td {
#
#                 text-align: right;
#
#                 min-width: 3em;
#
#             }
#
#             #T_cb199366_bc78_11e5_affb_80e65010311a * {
#
#                 border-color: #c0c0c0;
#
#             }
#
#             #T_cb199366_bc78_11e5_affb_80e65010311a td:nth-child(7) {
#
#                 background: #eee;
#
#                 font-weight: 500;
#
#             }
#
#
#         </style>
#
#         <table id="T_cb199366_bc78_11e5_affb_80e65010311a" None>
#
#
#         <thead>
#
#             <tr>
#
#                 <th class="blank">
#
#                 <th class="col_heading level0 col0">A
#
#                 <th class="col_heading level0 col1">B
#
#                 <th class="col_heading level0 col2">C
#
#                 <th class="col_heading level0 col3">D
#
#                 <th class="col_heading level0 col4">E
#
#                 <th class="col_heading level0 col5">Average
#
#             </tr>
#
#         </thead>
#         <tbody>
#
#             <tr>
#
#                 <th id="T_cb199366_bc78_11e5_affb_80e65010311a" class="row_heading level5 row0">
#
#                         0.0
#
#
#                 <td id="T_cb199366_bc78_11e5_affb_80e65010311arow0_col0" class="data row0 col0">
#
#                         1.0
#
#
#                 <td id="T_cb199366_bc78_11e5_affb_80e65010311arow0_col1" class="data row0 col1">
#
#                         1.329212
#
#
#                 <td id="T_cb199366_bc78_11e5_affb_80e65010311arow0_col2" class="data row0 col2">
#
#                         -0.770033
#
#
#                 <td id="T_cb199366_bc78_11e5_affb_80e65010311arow0_col3" class="data row0 col3">
#
#                         -0.31628
#
#
#                 <td id="T_cb199366_bc78_11e5_affb_80e65010311arow0_col4" class="data row0 col4">
#
#                         -0.99081
#
#
#                 <td id="T_cb199366_bc78_11e5_affb_80e65010311arow0_col5" class="data row0 col5">
#
#                         0.050418
#
#
#             </tr>
#
#             <tr>
#
#                 <th id="T_cb199366_bc78_11e5_affb_80e65010311a" class="row_heading level5 row1">
#
#                         1.0
#
#
#                 <td id="T_cb199366_bc78_11e5_affb_80e65010311arow1_col0" class="data row1 col0">
#
#                         2.0
#
#
#                 <td id="T_cb199366_bc78_11e5_affb_80e65010311arow1_col1" class="data row1 col1">
#
#                         -1.070816
#
#
#                 <td id="T_cb199366_bc78_11e5_affb_80e65010311arow1_col2" class="data row1 col2">
#
#                         -1.438713
#
#
#                 <td id="T_cb199366_bc78_11e5_affb_80e65010311arow1_col3" class="data row1 col3">
#
#                         0.564417
#
#
#                 <td id="T_cb199366_bc78_11e5_affb_80e65010311arow1_col4" class="data row1 col4">
#
#                         0.295722
#
#
#                 <td id="T_cb199366_bc78_11e5_affb_80e65010311arow1_col5" class="data row1 col5">
#
#                         0.070122
#
#
#             </tr>
#
#             <tr>
#
#                 <th id="T_cb199366_bc78_11e5_affb_80e65010311a" class="row_heading level5 row2">
#
#                         2.0
#
#
#                 <td id="T_cb199366_bc78_11e5_affb_80e65010311arow2_col0" class="data row2 col0">
#
#                         3.0
#
#
#                 <td id="T_cb199366_bc78_11e5_affb_80e65010311arow2_col1" class="data row2 col1">
#
#                         -1.626404
#
#
#                 <td id="T_cb199366_bc78_11e5_affb_80e65010311arow2_col2" class="data row2 col2">
#
#                         0.219565
#
#
#                 <td id="T_cb199366_bc78_11e5_affb_80e65010311arow2_col3" class="data row2 col3">
#
#                         0.678805
#
#
#                 <td id="T_cb199366_bc78_11e5_affb_80e65010311arow2_col4" class="data row2 col4">
#
#                         1.889273
#
#
#                 <td id="T_cb199366_bc78_11e5_affb_80e65010311arow2_col5" class="data row2 col5">
#
#                         0.832248
#
#
#             </tr>
#
#             <tr>
#
#                 <th id="T_cb199366_bc78_11e5_affb_80e65010311a" class="row_heading level5 row3">
#
#                         3.0
#
#
#                 <td id="T_cb199366_bc78_11e5_affb_80e65010311arow3_col0" class="data row3 col0">
#
#                         4.0
#
#
#                 <td id="T_cb199366_bc78_11e5_affb_80e65010311arow3_col1" class="data row3 col1">
#
#                         0.961538
#
#
#                 <td id="T_cb199366_bc78_11e5_affb_80e65010311arow3_col2" class="data row3 col2">
#
#                         0.104011
#
#
#                 <td id="T_cb199366_bc78_11e5_affb_80e65010311arow3_col3" class="data row3 col3">
#
#                         -0.481165
#
#
#                 <td id="T_cb199366_bc78_11e5_affb_80e65010311arow3_col4" class="data row3 col4">
#
#                         0.850229
#
#
#                 <td id="T_cb199366_bc78_11e5_affb_80e65010311arow3_col5" class="data row3 col5">
#
#                         1.086923
#
#
#             </tr>
#
#             <tr>
#
#                 <th id="T_cb199366_bc78_11e5_affb_80e65010311a" class="row_heading level5 row4">
#
#                         4.0
#
#
#                 <td id="T_cb199366_bc78_11e5_affb_80e65010311arow4_col0" class="data row4 col0">
#
#                         5.0
#
#
#                 <td id="T_cb199366_bc78_11e5_affb_80e65010311arow4_col1" class="data row4 col1">
#
#                         1.453425
#
#
#                 <td id="T_cb199366_bc78_11e5_affb_80e65010311arow4_col2" class="data row4 col2">
#
#                         1.057737
#
#
#                 <td id="T_cb199366_bc78_11e5_affb_80e65010311arow4_col3" class="data row4 col3">
#
#                         0.165562
#
#
#                 <td id="T_c

# %%
PrettyPandas(df).average(axis=None)
# Out:
#         <style  type="text/css" >
#
#             #T_cb24214f_bc78_11e5_a96f_80e65010311a th {
#
#                 background: #eee;
#
#                 font-weight: 500;
#
#             }
#
#             #T_cb24214f_bc78_11e5_a96f_80e65010311a td {
#
#                 text-align: right;
#
#                 min-width: 3em;
#
#             }
#
#             #T_cb24214f_bc78_11e5_a96f_80e65010311a * {
#
#                 border-color: #c0c0c0;
#
#             }
#
#             #T_cb24214f_bc78_11e5_a96f_80e65010311a tr:nth-child(11) {
#
#                 background: #eee;
#
#                 font-weight: 500;
#
#             }
#
#             #T_cb24214f_bc78_11e5_a96f_80e65010311a td:nth-child(7) {
#
#                 background: #eee;
#
#                 font-weight: 500;
#
#             }
#
#
#         </style>
#
#         <table id="T_cb24214f_bc78_11e5_a96f_80e65010311a" None>
#
#
#         <thead>
#
#             <tr>
#
#                 <th class="blank">
#
#                 <th class="col_heading level0 col0">A
#
#                 <th class="col_heading level0 col1">B
#
#                 <th class="col_heading level0 col2">C
#
#                 <th class="col_heading level0 col3">D
#
#                 <th class="col_heading level0 col4">E
#
#                 <th class="col_heading level0 col5">Average
#
#             </tr>
#
#         </thead>
#         <tbody>
#
#             <tr>
#
#                 <th id="T_cb24214f_bc78_11e5_a96f_80e65010311a" class="row_heading level5 row0">
#
#                         0.0
#
#
#                 <td id="T_cb24214f_bc78_11e5_a96f_80e65010311arow0_col0" class="data row0 col0">
#
#                         1.0
#
#
#                 <td id="T_cb24214f_bc78_11e5_a96f_80e65010311arow0_col1" class="data row0 col1">
#
#                         1.329212
#
#
#                 <td id="T_cb24214f_bc78_11e5_a96f_80e65010311arow0_col2" class="data row0 col2">
#
#                         -0.770033
#
#
#                 <td id="T_cb24214f_bc78_11e5_a96f_80e65010311arow0_col3" class="data row0 col3">
#
#                         -0.31628
#
#
#                 <td id="T_cb24214f_bc78_11e5_a96f_80e65010311arow0_col4" class="data row0 col4">
#
#                         -0.99081
#
#
#                 <td id="T_cb24214f_bc78_11e5_a96f_80e65010311arow0_col5" class="data row0 col5">
#
#                         0.050418
#
#
#             </tr>
#
#             <tr>
#
#                 <th id="T_cb24214f_bc78_11e5_a96f_80e65010311a" class="row_heading level5 row1">
#
#                         1.0
#
#
#                 <td id="T_cb24214f_bc78_11e5_a96f_80e65010311arow1_col0" class="data row1 col0">
#
#                         2.0
#
#
#                 <td id="T_cb24214f_bc78_11e5_a96f_80e65010311arow1_col1" class="data row1 col1">
#
#                         -1.070816
#
#
#                 <td id="T_cb24214f_bc78_11e5_a96f_80e65010311arow1_col2" class="data row1 col2">
#
#                         -1.438713
#
#
#                 <td id="T_cb24214f_bc78_11e5_a96f_80e65010311arow1_col3" class="data row1 col3">
#
#                         0.564417
#
#
#                 <td id="T_cb24214f_bc78_11e5_a96f_80e65010311arow1_col4" class="data row1 col4">
#
#                         0.295722
#
#
#                 <td id="T_cb24214f_bc78_11e5_a96f_80e65010311arow1_col5" class="data row1 col5">
#
#                         0.070122
#
#
#             </tr>
#
#             <tr>
#
#                 <th id="T_cb24214f_bc78_11e5_a96f_80e65010311a" class="row_heading level5 row2">
#
#                         2.0
#
#
#                 <td id="T_cb24214f_bc78_11e5_a96f_80e65010311arow2_col0" class="data row2 col0">
#
#                         3.0
#
#
#                 <td id="T_cb24214f_bc78_11e5_a96f_80e65010311arow2_col1" class="data row2 col1">
#
#                         -1.626404
#
#
#                 <td id="T_cb24214f_bc78_11e5_a96f_80e65010311arow2_col2" class="data row2 col2">
#
#                         0.219565
#
#
#                 <td id="T_cb24214f_bc78_11e5_a96f_80e65010311arow2_col3" class="data row2 col3">
#
#                         0.678805
#
#
#                 <td id="T_cb24214f_bc78_11e5_a96f_80e65010311arow2_col4" class="data row2 col4">
#
#                         1.889273
#
#
#                 <td id="T_cb24214f_bc78_11e5_a96f_80e65010311arow2_col5" class="data row2 col5">
#
#                         0.832248
#
#
#             </tr>
#
#             <tr>
#
#                 <th id="T_cb24214f_bc78_11e5_a96f_80e65010311a" class="row_heading level5 row3">
#
#                         3.0
#
#
#                 <td id="T_cb24214f_bc78_11e5_a96f_80e65010311arow3_col0" class="data row3 col0">
#
#                         4.0
#
#
#                 <td id="T_cb24214f_bc78_11e5_a96f_80e65010311arow3_col1" class="data row3 col1">
#
#                         0.961538
#
#
#                 <td id="T_cb24214f_bc78_11e5_a96f_80e65010311arow3_col2" class="data row3 col2">
#
#                         0.104011
#
#
#                 <td id="T_cb24214f_bc78_11e5_a96f_80e65010311arow3_col3" class="data row3 col3">
#
#                         -0.481165
#
#
#                 <td id="T_cb24214f_bc78_11e5_a96f_80e65010311arow3_col4" class="data row3 col4">
#
#                         0.850229
#
#
#                 <td id="T_cb24214f_bc78_11e5_a96f_80e65010311arow3_col5" class="data row3 col5">
#
#                         1.086923
#
#
#             </tr>
#
#             <tr>
#
#                 <th id="T_cb24214f_bc78_11e5_a96f_80e65010311a" class="row_heading level5 row4">
#
#                         4.0
#
#
#                 <td id="T_cb24214f_bc78_11e5_a96f_80e65010311arow4_col0" class="data row4 col0">
#
#                         5.0
#
#
#                 <td id="T_cb24214f_bc78_11e5_a96f_80e65010311arow4_col1" class="data row4 col1">
#
#                         1.453425
#
#
#                 <td id="T_cb24214f_bc78_11e5_a96f_80e65010311arow4_col2" class="data row4 col2">
#
#                         1.057737

# %%
PrettyPandas(df).min().max()
# Out:
#         <style  type="text/css" >
#
#             #T_cb27ac80_bc78_11e5_b7b8_80e65010311a th {
#
#                 background: #eee;
#
#                 font-weight: 500;
#
#             }
#
#             #T_cb27ac80_bc78_11e5_b7b8_80e65010311a td {
#
#                 text-align: right;
#
#                 min-width: 3em;
#
#             }
#
#             #T_cb27ac80_bc78_11e5_b7b8_80e65010311a * {
#
#                 border-color: #c0c0c0;
#
#             }
#
#             #T_cb27ac80_bc78_11e5_b7b8_80e65010311a tr:nth-child(11) {
#
#                 background: #eee;
#
#                 font-weight: 500;
#
#             }
#
#             #T_cb27ac80_bc78_11e5_b7b8_80e65010311a tr:nth-child(12) {
#
#                 background: #eee;
#
#                 font-weight: 500;
#
#             }
#
#
#         </style>
#
#         <table id="T_cb27ac80_bc78_11e5_b7b8_80e65010311a" None>
#
#
#         <thead>
#
#             <tr>
#
#                 <th class="blank">
#
#                 <th class="col_heading level0 col0">A
#
#                 <th class="col_heading level0 col1">B
#
#                 <th class="col_heading level0 col2">C
#
#                 <th class="col_heading level0 col3">D
#
#                 <th class="col_heading level0 col4">E
#
#             </tr>
#
#         </thead>
#         <tbody>
#
#             <tr>
#
#                 <th id="T_cb27ac80_bc78_11e5_b7b8_80e65010311a" class="row_heading level4 row0">
#
#                         0.0
#
#
#                 <td id="T_cb27ac80_bc78_11e5_b7b8_80e65010311arow0_col0" class="data row0 col0">
#
#                         1.0
#
#
#                 <td id="T_cb27ac80_bc78_11e5_b7b8_80e65010311arow0_col1" class="data row0 col1">
#
#                         1.329212
#
#
#                 <td id="T_cb27ac80_bc78_11e5_b7b8_80e65010311arow0_col2" class="data row0 col2">
#
#                         -0.770033
#
#
#                 <td id="T_cb27ac80_bc78_11e5_b7b8_80e65010311arow0_col3" class="data row0 col3">
#
#                         -0.31628
#
#
#                 <td id="T_cb27ac80_bc78_11e5_b7b8_80e65010311arow0_col4" class="data row0 col4">
#
#                         -0.99081
#
#
#             </tr>
#
#             <tr>
#
#                 <th id="T_cb27ac80_bc78_11e5_b7b8_80e65010311a" class="row_heading level4 row1">
#
#                         1.0
#
#
#                 <td id="T_cb27ac80_bc78_11e5_b7b8_80e65010311arow1_col0" class="data row1 col0">
#
#                         2.0
#
#
#                 <td id="T_cb27ac80_bc78_11e5_b7b8_80e65010311arow1_col1" class="data row1 col1">
#
#                         -1.070816
#
#
#                 <td id="T_cb27ac80_bc78_11e5_b7b8_80e65010311arow1_col2" class="data row1 col2">
#
#                         -1.438713
#
#
#                 <td id="T_cb27ac80_bc78_11e5_b7b8_80e65010311arow1_col3" class="data row1 col3">
#
#                         0.564417
#
#
#                 <td id="T_cb27ac80_bc78_11e5_b7b8_80e65010311arow1_col4" class="data row1 col4">
#
#                         0.295722
#
#
#             </tr>
#
#             <tr>
#
#                 <th id="T_cb27ac80_bc78_11e5_b7b8_80e65010311a" class="row_heading level4 row2">
#
#                         2.0
#
#
#                 <td id="T_cb27ac80_bc78_11e5_b7b8_80e65010311arow2_col0" class="data row2 col0">
#
#                         3.0
#
#
#                 <td id="T_cb27ac80_bc78_11e5_b7b8_80e65010311arow2_col1" class="data row2 col1">
#
#                         -1.626404
#
#
#                 <td id="T_cb27ac80_bc78_11e5_b7b8_80e65010311arow2_col2" class="data row2 col2">
#
#                         0.219565
#
#
#                 <td id="T_cb27ac80_bc78_11e5_b7b8_80e65010311arow2_col3" class="data row2 col3">
#
#                         0.678805
#
#
#                 <td id="T_cb27ac80_bc78_11e5_b7b8_80e65010311arow2_col4" class="data row2 col4">
#
#                         1.889273
#
#
#             </tr>
#
#             <tr>
#
#                 <th id="T_cb27ac80_bc78_11e5_b7b8_80e65010311a" class="row_heading level4 row3">
#
#                         3.0
#
#
#                 <td id="T_cb27ac80_bc78_11e5_b7b8_80e65010311arow3_col0" class="data row3 col0">
#
#                         4.0
#
#
#                 <td id="T_cb27ac80_bc78_11e5_b7b8_80e65010311arow3_col1" class="data row3 col1">
#
#                         0.961538
#
#
#                 <td id="T_cb27ac80_bc78_11e5_b7b8_80e65010311arow3_col2" class="data row3 col2">
#
#                         0.104011
#
#
#                 <td id="T_cb27ac80_bc78_11e5_b7b8_80e65010311arow3_col3" class="data row3 col3">
#
#                         -0.481165
#
#
#                 <td id="T_cb27ac80_bc78_11e5_b7b8_80e65010311arow3_col4" class="data row3 col4">
#
#                         0.850229
#
#
#             </tr>
#
#             <tr>
#
#                 <th id="T_cb27ac80_bc78_11e5_b7b8_80e65010311a" class="row_heading level4 row4">
#
#                         4.0
#
#
#                 <td id="T_cb27ac80_bc78_11e5_b7b8_80e65010311arow4_col0" class="data row4 col0">
#
#                         5.0
#
#
#                 <td id="T_cb27ac80_bc78_11e5_b7b8_80e65010311arow4_col1" class="data row4 col1">
#
#                         1.453425
#
#
#                 <td id="T_cb27ac80_bc78_11e5_b7b8_80e65010311arow4_col2" class="data row4 col2">
#
#                         1.057737
#
#
#                 <td id="T_cb27ac80_bc78_11e5_b7b8_80e65010311arow4_col3" class="data row4 col3">
#
#                         0.165562
#
#
#                 <td id="T_cb27ac80_bc78_11e5_b7b8_80e65010311arow4_col4" class="data row4 col4">
#
#                         0.515018
#
#
#             </tr>
#
#             <tr>
#
#                 <th id="T_cb27ac80_bc78_11e5_b7b8_80e65010311a" class="row_heading level4 row5">
#
#                         5.0
#
#
#                 <td id="T_cb27ac80_bc78_11e5_b7b8_80e65010311arow5_col0" class="data row5 col0">
#
#                         6.0
#
#
#                 <td id="T_cb27ac80_b

# %%
PrettyPandas(df).summary(np.mean, "Average")
# Out:
#         <style  type="text/css" >
#
#             #T_cb2bb968_bc78_11e5_8c88_80e65010311a th {
#
#                 background: #eee;
#
#                 font-weight: 500;
#
#             }
#
#             #T_cb2bb968_bc78_11e5_8c88_80e65010311a td {
#
#                 text-align: right;
#
#                 min-width: 3em;
#
#             }
#
#             #T_cb2bb968_bc78_11e5_8c88_80e65010311a * {
#
#                 border-color: #c0c0c0;
#
#             }
#
#             #T_cb2bb968_bc78_11e5_8c88_80e65010311a tr:nth-child(11) {
#
#                 background: #eee;
#
#                 font-weight: 500;
#
#             }
#
#
#         </style>
#
#         <table id="T_cb2bb968_bc78_11e5_8c88_80e65010311a" None>
#
#
#         <thead>
#
#             <tr>
#
#                 <th class="blank">
#
#                 <th class="col_heading level0 col0">A
#
#                 <th class="col_heading level0 col1">B
#
#                 <th class="col_heading level0 col2">C
#
#                 <th class="col_heading level0 col3">D
#
#                 <th class="col_heading level0 col4">E
#
#             </tr>
#
#         </thead>
#         <tbody>
#
#             <tr>
#
#                 <th id="T_cb2bb968_bc78_11e5_8c88_80e65010311a" class="row_heading level4 row0">
#
#                         0.0
#
#
#                 <td id="T_cb2bb968_bc78_11e5_8c88_80e65010311arow0_col0" class="data row0 col0">
#
#                         1.0
#
#
#                 <td id="T_cb2bb968_bc78_11e5_8c88_80e65010311arow0_col1" class="data row0 col1">
#
#                         1.329212
#
#
#                 <td id="T_cb2bb968_bc78_11e5_8c88_80e65010311arow0_col2" class="data row0 col2">
#
#                         -0.770033
#
#
#                 <td id="T_cb2bb968_bc78_11e5_8c88_80e65010311arow0_col3" class="data row0 col3">
#
#                         -0.31628
#
#
#                 <td id="T_cb2bb968_bc78_11e5_8c88_80e65010311arow0_col4" class="data row0 col4">
#
#                         -0.99081
#
#
#             </tr>
#
#             <tr>
#
#                 <th id="T_cb2bb968_bc78_11e5_8c88_80e65010311a" class="row_heading level4 row1">
#
#                         1.0
#
#
#                 <td id="T_cb2bb968_bc78_11e5_8c88_80e65010311arow1_col0" class="data row1 col0">
#
#                         2.0
#
#
#                 <td id="T_cb2bb968_bc78_11e5_8c88_80e65010311arow1_col1" class="data row1 col1">
#
#                         -1.070816
#
#
#                 <td id="T_cb2bb968_bc78_11e5_8c88_80e65010311arow1_col2" class="data row1 col2">
#
#                         -1.438713
#
#
#                 <td id="T_cb2bb968_bc78_11e5_8c88_80e65010311arow1_col3" class="data row1 col3">
#
#                         0.564417
#
#
#                 <td id="T_cb2bb968_bc78_11e5_8c88_80e65010311arow1_col4" class="data row1 col4">
#
#                         0.295722
#
#
#             </tr>
#
#             <tr>
#
#                 <th id="T_cb2bb968_bc78_11e5_8c88_80e65010311a" class="row_heading level4 row2">
#
#                         2.0
#
#
#                 <td id="T_cb2bb968_bc78_11e5_8c88_80e65010311arow2_col0" class="data row2 col0">
#
#                         3.0
#
#
#                 <td id="T_cb2bb968_bc78_11e5_8c88_80e65010311arow2_col1" class="data row2 col1">
#
#                         -1.626404
#
#
#                 <td id="T_cb2bb968_bc78_11e5_8c88_80e65010311arow2_col2" class="data row2 col2">
#
#                         0.219565
#
#
#                 <td id="T_cb2bb968_bc78_11e5_8c88_80e65010311arow2_col3" class="data row2 col3">
#
#                         0.678805
#
#
#                 <td id="T_cb2bb968_bc78_11e5_8c88_80e65010311arow2_col4" class="data row2 col4">
#
#                         1.889273
#
#
#             </tr>
#
#             <tr>
#
#                 <th id="T_cb2bb968_bc78_11e5_8c88_80e65010311a" class="row_heading level4 row3">
#
#                         3.0
#
#
#                 <td id="T_cb2bb968_bc78_11e5_8c88_80e65010311arow3_col0" class="data row3 col0">
#
#                         4.0
#
#
#                 <td id="T_cb2bb968_bc78_11e5_8c88_80e65010311arow3_col1" class="data row3 col1">
#
#                         0.961538
#
#
#                 <td id="T_cb2bb968_bc78_11e5_8c88_80e65010311arow3_col2" class="data row3 col2">
#
#                         0.104011
#
#
#                 <td id="T_cb2bb968_bc78_11e5_8c88_80e65010311arow3_col3" class="data row3 col3">
#
#                         -0.481165
#
#
#                 <td id="T_cb2bb968_bc78_11e5_8c88_80e65010311arow3_col4" class="data row3 col4">
#
#                         0.850229
#
#
#             </tr>
#
#             <tr>
#
#                 <th id="T_cb2bb968_bc78_11e5_8c88_80e65010311a" class="row_heading level4 row4">
#
#                         4.0
#
#
#                 <td id="T_cb2bb968_bc78_11e5_8c88_80e65010311arow4_col0" class="data row4 col0">
#
#                         5.0
#
#
#                 <td id="T_cb2bb968_bc78_11e5_8c88_80e65010311arow4_col1" class="data row4 col1">
#
#                         1.453425
#
#
#                 <td id="T_cb2bb968_bc78_11e5_8c88_80e65010311arow4_col2" class="data row4 col2">
#
#                         1.057737
#
#
#                 <td id="T_cb2bb968_bc78_11e5_8c88_80e65010311arow4_col3" class="data row4 col3">
#
#                         0.165562
#
#
#                 <td id="T_cb2bb968_bc78_11e5_8c88_80e65010311arow4_col4" class="data row4 col4">
#
#                         0.515018
#
#
#             </tr>
#
#             <tr>
#
#                 <th id="T_cb2bb968_bc78_11e5_8c88_80e65010311a" class="row_heading level4 row5">
#
#                         5.0
#
#
#                 <td id="T_cb2bb968_bc78_11e5_8c88_80e65010311arow5_col0" class="data row5 col0">
#
#                         6.0
#
#
#                 <td id="T_cb2bb968_bc78_11e5_8c88_80e65010311arow5_col1" class="data row5 col1">
#
#                         -1.336936
#
#
#                 <td id="T_cb2bb968_bc78_11e5_8c

# %% [markdown]
# ### Multiple Summaries

# %%
PrettyPandas(df).multi_summary([np.mean, np.sum],
                               ['Average', 'Total'],
                               axis=0)
# Out:
#         <style  type="text/css" >
#
#             #T_cb2f0e11_bc78_11e5_860d_80e65010311a th {
#
#                 background: #eee;
#
#                 font-weight: 500;
#
#             }
#
#             #T_cb2f0e11_bc78_11e5_860d_80e65010311a td {
#
#                 text-align: right;
#
#                 min-width: 3em;
#
#             }
#
#             #T_cb2f0e11_bc78_11e5_860d_80e65010311a * {
#
#                 border-color: #c0c0c0;
#
#             }
#
#             #T_cb2f0e11_bc78_11e5_860d_80e65010311a tr:nth-child(11) {
#
#                 background: #eee;
#
#                 font-weight: 500;
#
#             }
#
#             #T_cb2f0e11_bc78_11e5_860d_80e65010311a tr:nth-child(12) {
#
#                 background: #eee;
#
#                 font-weight: 500;
#
#             }
#
#
#         </style>
#
#         <table id="T_cb2f0e11_bc78_11e5_860d_80e65010311a" None>
#
#
#         <thead>
#
#             <tr>
#
#                 <th class="blank">
#
#                 <th class="col_heading level0 col0">A
#
#                 <th class="col_heading level0 col1">B
#
#                 <th class="col_heading level0 col2">C
#
#                 <th class="col_heading level0 col3">D
#
#                 <th class="col_heading level0 col4">E
#
#             </tr>
#
#         </thead>
#         <tbody>
#
#             <tr>
#
#                 <th id="T_cb2f0e11_bc78_11e5_860d_80e65010311a" class="row_heading level4 row0">
#
#                         0.0
#
#
#                 <td id="T_cb2f0e11_bc78_11e5_860d_80e65010311arow0_col0" class="data row0 col0">
#
#                         1.0
#
#
#                 <td id="T_cb2f0e11_bc78_11e5_860d_80e65010311arow0_col1" class="data row0 col1">
#
#                         1.329212
#
#
#                 <td id="T_cb2f0e11_bc78_11e5_860d_80e65010311arow0_col2" class="data row0 col2">
#
#                         -0.770033
#
#
#                 <td id="T_cb2f0e11_bc78_11e5_860d_80e65010311arow0_col3" class="data row0 col3">
#
#                         -0.31628
#
#
#                 <td id="T_cb2f0e11_bc78_11e5_860d_80e65010311arow0_col4" class="data row0 col4">
#
#                         -0.99081
#
#
#             </tr>
#
#             <tr>
#
#                 <th id="T_cb2f0e11_bc78_11e5_860d_80e65010311a" class="row_heading level4 row1">
#
#                         1.0
#
#
#                 <td id="T_cb2f0e11_bc78_11e5_860d_80e65010311arow1_col0" class="data row1 col0">
#
#                         2.0
#
#
#                 <td id="T_cb2f0e11_bc78_11e5_860d_80e65010311arow1_col1" class="data row1 col1">
#
#                         -1.070816
#
#
#                 <td id="T_cb2f0e11_bc78_11e5_860d_80e65010311arow1_col2" class="data row1 col2">
#
#                         -1.438713
#
#
#                 <td id="T_cb2f0e11_bc78_11e5_860d_80e65010311arow1_col3" class="data row1 col3">
#
#                         0.564417
#
#
#                 <td id="T_cb2f0e11_bc78_11e5_860d_80e65010311arow1_col4" class="data row1 col4">
#
#                         0.295722
#
#
#             </tr>
#
#             <tr>
#
#                 <th id="T_cb2f0e11_bc78_11e5_860d_80e65010311a" class="row_heading level4 row2">
#
#                         2.0
#
#
#                 <td id="T_cb2f0e11_bc78_11e5_860d_80e65010311arow2_col0" class="data row2 col0">
#
#                         3.0
#
#
#                 <td id="T_cb2f0e11_bc78_11e5_860d_80e65010311arow2_col1" class="data row2 col1">
#
#                         -1.626404
#
#
#                 <td id="T_cb2f0e11_bc78_11e5_860d_80e65010311arow2_col2" class="data row2 col2">
#
#                         0.219565
#
#
#                 <td id="T_cb2f0e11_bc78_11e5_860d_80e65010311arow2_col3" class="data row2 col3">
#
#                         0.678805
#
#
#                 <td id="T_cb2f0e11_bc78_11e5_860d_80e65010311arow2_col4" class="data row2 col4">
#
#                         1.889273
#
#
#             </tr>
#
#             <tr>
#
#                 <th id="T_cb2f0e11_bc78_11e5_860d_80e65010311a" class="row_heading level4 row3">
#
#                         3.0
#
#
#                 <td id="T_cb2f0e11_bc78_11e5_860d_80e65010311arow3_col0" class="data row3 col0">
#
#                         4.0
#
#
#                 <td id="T_cb2f0e11_bc78_11e5_860d_80e65010311arow3_col1" class="data row3 col1">
#
#                         0.961538
#
#
#                 <td id="T_cb2f0e11_bc78_11e5_860d_80e65010311arow3_col2" class="data row3 col2">
#
#                         0.104011
#
#
#                 <td id="T_cb2f0e11_bc78_11e5_860d_80e65010311arow3_col3" class="data row3 col3">
#
#                         -0.481165
#
#
#                 <td id="T_cb2f0e11_bc78_11e5_860d_80e65010311arow3_col4" class="data row3 col4">
#
#                         0.850229
#
#
#             </tr>
#
#             <tr>
#
#                 <th id="T_cb2f0e11_bc78_11e5_860d_80e65010311a" class="row_heading level4 row4">
#
#                         4.0
#
#
#                 <td id="T_cb2f0e11_bc78_11e5_860d_80e65010311arow4_col0" class="data row4 col0">
#
#                         5.0
#
#
#                 <td id="T_cb2f0e11_bc78_11e5_860d_80e65010311arow4_col1" class="data row4 col1">
#
#                         1.453425
#
#
#                 <td id="T_cb2f0e11_bc78_11e5_860d_80e65010311arow4_col2" class="data row4 col2">
#
#                         1.057737
#
#
#                 <td id="T_cb2f0e11_bc78_11e5_860d_80e65010311arow4_col3" class="data row4 col3">
#
#                         0.165562
#
#
#                 <td id="T_cb2f0e11_bc78_11e5_860d_80e65010311arow4_col4" class="data row4 col4">
#
#                         0.515018
#
#
#             </tr>
#
#             <tr>
#
#                 <th id="T_cb2f0e11_bc78_11e5_860d_80e65010311a" class="row_heading level4 row5">
#
#                         5.0
#
#
#                 <td id="T_cb2f0e11_bc78_11e5_860d_80e65010311arow5_col0" class="data row5 col0">
#
#                         6.0
#
#
#                 <td id="T_cb2f0e11_b

# %% [markdown]
# ## Number Formatting

# %%
PrettyPandas(df).as_percent()
# Out:
#         <style  type="text/css" >
#
#             #T_cb33c338_bc78_11e5_a79b_80e65010311a th {
#
#                 background: #eee;
#
#                 font-weight: 500;
#
#             }
#
#             #T_cb33c338_bc78_11e5_a79b_80e65010311a td {
#
#                 text-align: right;
#
#                 min-width: 3em;
#
#             }
#
#             #T_cb33c338_bc78_11e5_a79b_80e65010311a * {
#
#                 border-color: #c0c0c0;
#
#             }
#
#
#         </style>
#
#         <table id="T_cb33c338_bc78_11e5_a79b_80e65010311a" None>
#
#
#         <thead>
#
#             <tr>
#
#                 <th class="blank">
#
#                 <th class="col_heading level0 col0">A
#
#                 <th class="col_heading level0 col1">B
#
#                 <th class="col_heading level0 col2">C
#
#                 <th class="col_heading level0 col3">D
#
#                 <th class="col_heading level0 col4">E
#
#             </tr>
#
#         </thead>
#         <tbody>
#
#             <tr>
#
#                 <th id="T_cb33c338_bc78_11e5_a79b_80e65010311a" class="row_heading level4 row0">
#
#                         0.0
#
#
#                 <td id="T_cb33c338_bc78_11e5_a79b_80e65010311arow0_col0" class="data row0 col0">
#
#                         100.000000%
#
#
#                 <td id="T_cb33c338_bc78_11e5_a79b_80e65010311arow0_col1" class="data row0 col1">
#
#                         132.921217%
#
#
#                 <td id="T_cb33c338_bc78_11e5_a79b_80e65010311arow0_col2" class="data row0 col2">
#
#                         -77.003345%
#
#
#                 <td id="T_cb33c338_bc78_11e5_a79b_80e65010311arow0_col3" class="data row0 col3">
#
#                         -31.628036%
#
#
#                 <td id="T_cb33c338_bc78_11e5_a79b_80e65010311arow0_col4" class="data row0 col4">
#
#                         -99.081039%
#
#
#             </tr>
#
#             <tr>
#
#                 <th id="T_cb33c338_bc78_11e5_a79b_80e65010311a" class="row_heading level4 row1">
#
#                         1.0
#
#
#                 <td id="T_cb33c338_bc78_11e5_a79b_80e65010311arow1_col0" class="data row1 col0">
#
#                         200.000000%
#
#
#                 <td id="T_cb33c338_bc78_11e5_a79b_80e65010311arow1_col1" class="data row1 col1">
#
#                         -107.081626%
#
#
#                 <td id="T_cb33c338_bc78_11e5_a79b_80e65010311arow1_col2" class="data row1 col2">
#
#                         -143.871328%
#
#
#                 <td id="T_cb33c338_bc78_11e5_a79b_80e65010311arow1_col3" class="data row1 col3">
#
#                         56.441685%
#
#
#                 <td id="T_cb33c338_bc78_11e5_a79b_80e65010311arow1_col4" class="data row1 col4">
#
#                         29.572189%
#
#
#             </tr>
#
#             <tr>
#
#                 <th id="T_cb33c338_bc78_11e5_a79b_80e65010311a" class="row_heading level4 row2">
#
#                         2.0
#
#
#                 <td id="T_cb33c338_bc78_11e5_a79b_80e65010311arow2_col0" class="data row2 col0">
#
#                         300.000000%
#
#
#                 <td id="T_cb33c338_bc78_11e5_a79b_80e65010311arow2_col1" class="data row2 col1">
#
#                         -162.640423%
#
#
#                 <td id="T_cb33c338_bc78_11e5_a79b_80e65010311arow2_col2" class="data row2 col2">
#
#                         21.956520%
#
#
#                 <td id="T_cb33c338_bc78_11e5_a79b_80e65010311arow2_col3" class="data row2 col3">
#
#                         67.880480%
#
#
#                 <td id="T_cb33c338_bc78_11e5_a79b_80e65010311arow2_col4" class="data row2 col4">
#
#                         188.927273%
#
#
#             </tr>
#
#             <tr>
#
#                 <th id="T_cb33c338_bc78_11e5_a79b_80e65010311a" class="row_heading level4 row3">
#
#                         3.0
#
#
#                 <td id="T_cb33c338_bc78_11e5_a79b_80e65010311arow3_col0" class="data row3 col0">
#
#                         400.000000%
#
#
#                 <td id="T_cb33c338_bc78_11e5_a79b_80e65010311arow3_col1" class="data row3 col1">
#
#                         96.153840%
#
#
#                 <td id="T_cb33c338_bc78_11e5_a79b_80e65010311arow3_col2" class="data row3 col2">
#
#                         10.401120%
#
#
#                 <td id="T_cb33c338_bc78_11e5_a79b_80e65010311arow3_col3" class="data row3 col3">
#
#                         -48.116532%
#
#
#                 <td id="T_cb33c338_bc78_11e5_a79b_80e65010311arow3_col4" class="data row3 col4">
#
#                         85.022853%
#
#
#             </tr>
#
#             <tr>
#
#                 <th id="T_cb33c338_bc78_11e5_a79b_80e65010311a" class="row_heading level4 row4">
#
#                         4.0
#
#
#                 <td id="T_cb33c338_bc78_11e5_a79b_80e65010311arow4_col0" class="data row4 col0">
#
#                         500.000000%
#
#
#                 <td id="T_cb33c338_bc78_11e5_a79b_80e65010311arow4_col1" class="data row4 col1">
#
#                         145.342467%
#
#
#                 <td id="T_cb33c338_bc78_11e5_a79b_80e65010311arow4_col2" class="data row4 col2">
#
#                         105.773744%
#
#
#                 <td id="T_cb33c338_bc78_11e5_a79b_80e65010311arow4_col3" class="data row4 col3">
#
#                         16.556161%
#
#
#                 <td id="T_cb33c338_bc78_11e5_a79b_80e65010311arow4_col4" class="data row4 col4">
#
#                         51.501838%
#
#
#             </tr>
#
#             <tr>
#
#                 <th id="T_cb33c338_bc78_11e5_a79b_80e65010311a" class="row_heading level4 row5">
#
#                         5.0
#
#
#                 <td id="T_cb33c338_bc78_11e5_a79b_80e65010311arow5_col0" class="data row5 col0">
#
#                         600.000000%
#
#
#                 <td id="T_cb33c338_bc78_11e5_a79b_80e65010311arow5_col1" class="data row5 col1">
#
#                         -133.693569%
#
#
#                 <td id="T_cb33c338_bc78_11e5_a79b_80e65010311arow5_col2" class="data row5 col2">
#
#                         56.286

# %%
PrettyPandas(df).as_money()
# Out:
#         <style  type="text/css" >
#
#             #T_cb395457_bc78_11e5_aede_80e65010311a th {
#
#                 background: #eee;
#
#                 font-weight: 500;
#
#             }
#
#             #T_cb395457_bc78_11e5_aede_80e65010311a td {
#
#                 text-align: right;
#
#                 min-width: 3em;
#
#             }
#
#             #T_cb395457_bc78_11e5_aede_80e65010311a * {
#
#                 border-color: #c0c0c0;
#
#             }
#
#
#         </style>
#
#         <table id="T_cb395457_bc78_11e5_aede_80e65010311a" None>
#
#
#         <thead>
#
#             <tr>
#
#                 <th class="blank">
#
#                 <th class="col_heading level0 col0">A
#
#                 <th class="col_heading level0 col1">B
#
#                 <th class="col_heading level0 col2">C
#
#                 <th class="col_heading level0 col3">D
#
#                 <th class="col_heading level0 col4">E
#
#             </tr>
#
#         </thead>
#         <tbody>
#
#             <tr>
#
#                 <th id="T_cb395457_bc78_11e5_aede_80e65010311a" class="row_heading level4 row0">
#
#                         0.0
#
#
#                 <td id="T_cb395457_bc78_11e5_aede_80e65010311arow0_col0" class="data row0 col0">
#
#                         $1.000000
#
#
#                 <td id="T_cb395457_bc78_11e5_aede_80e65010311arow0_col1" class="data row0 col1">
#
#                         $1.329212
#
#
#                 <td id="T_cb395457_bc78_11e5_aede_80e65010311arow0_col2" class="data row0 col2">
#
#                         $-0.770033
#
#
#                 <td id="T_cb395457_bc78_11e5_aede_80e65010311arow0_col3" class="data row0 col3">
#
#                         $-0.316280
#
#
#                 <td id="T_cb395457_bc78_11e5_aede_80e65010311arow0_col4" class="data row0 col4">
#
#                         $-0.990810
#
#
#             </tr>
#
#             <tr>
#
#                 <th id="T_cb395457_bc78_11e5_aede_80e65010311a" class="row_heading level4 row1">
#
#                         1.0
#
#
#                 <td id="T_cb395457_bc78_11e5_aede_80e65010311arow1_col0" class="data row1 col0">
#
#                         $2.000000
#
#
#                 <td id="T_cb395457_bc78_11e5_aede_80e65010311arow1_col1" class="data row1 col1">
#
#                         $-1.070816
#
#
#                 <td id="T_cb395457_bc78_11e5_aede_80e65010311arow1_col2" class="data row1 col2">
#
#                         $-1.438713
#
#
#                 <td id="T_cb395457_bc78_11e5_aede_80e65010311arow1_col3" class="data row1 col3">
#
#                         $0.564417
#
#
#                 <td id="T_cb395457_bc78_11e5_aede_80e65010311arow1_col4" class="data row1 col4">
#
#                         $0.295722
#
#
#             </tr>
#
#             <tr>
#
#                 <th id="T_cb395457_bc78_11e5_aede_80e65010311a" class="row_heading level4 row2">
#
#                         2.0
#
#
#                 <td id="T_cb395457_bc78_11e5_aede_80e65010311arow2_col0" class="data row2 col0">
#
#                         $3.000000
#
#
#                 <td id="T_cb395457_bc78_11e5_aede_80e65010311arow2_col1" class="data row2 col1">
#
#                         $-1.626404
#
#
#                 <td id="T_cb395457_bc78_11e5_aede_80e65010311arow2_col2" class="data row2 col2">
#
#                         $0.219565
#
#
#                 <td id="T_cb395457_bc78_11e5_aede_80e65010311arow2_col3" class="data row2 col3">
#
#                         $0.678805
#
#
#                 <td id="T_cb395457_bc78_11e5_aede_80e65010311arow2_col4" class="data row2 col4">
#
#                         $1.889273
#
#
#             </tr>
#
#             <tr>
#
#                 <th id="T_cb395457_bc78_11e5_aede_80e65010311a" class="row_heading level4 row3">
#
#                         3.0
#
#
#                 <td id="T_cb395457_bc78_11e5_aede_80e65010311arow3_col0" class="data row3 col0">
#
#                         $4.000000
#
#
#                 <td id="T_cb395457_bc78_11e5_aede_80e65010311arow3_col1" class="data row3 col1">
#
#                         $0.961538
#
#
#                 <td id="T_cb395457_bc78_11e5_aede_80e65010311arow3_col2" class="data row3 col2">
#
#                         $0.104011
#
#
#                 <td id="T_cb395457_bc78_11e5_aede_80e65010311arow3_col3" class="data row3 col3">
#
#                         $-0.481165
#
#
#                 <td id="T_cb395457_bc78_11e5_aede_80e65010311arow3_col4" class="data row3 col4">
#
#                         $0.850229
#
#
#             </tr>
#
#             <tr>
#
#                 <th id="T_cb395457_bc78_11e5_aede_80e65010311a" class="row_heading level4 row4">
#
#                         4.0
#
#
#                 <td id="T_cb395457_bc78_11e5_aede_80e65010311arow4_col0" class="data row4 col0">
#
#                         $5.000000
#
#
#                 <td id="T_cb395457_bc78_11e5_aede_80e65010311arow4_col1" class="data row4 col1">
#
#                         $1.453425
#
#
#                 <td id="T_cb395457_bc78_11e5_aede_80e65010311arow4_col2" class="data row4 col2">
#
#                         $1.057737
#
#
#                 <td id="T_cb395457_bc78_11e5_aede_80e65010311arow4_col3" class="data row4 col3">
#
#                         $0.165562
#
#
#                 <td id="T_cb395457_bc78_11e5_aede_80e65010311arow4_col4" class="data row4 col4">
#
#                         $0.515018
#
#
#             </tr>
#
#             <tr>
#
#                 <th id="T_cb395457_bc78_11e5_aede_80e65010311a" class="row_heading level4 row5">
#
#                         5.0
#
#
#                 <td id="T_cb395457_bc78_11e5_aede_80e65010311arow5_col0" class="data row5 col0">
#
#                         $6.000000
#
#
#                 <td id="T_cb395457_bc78_11e5_aede_80e65010311arow5_col1" class="data row5 col1">
#
#                         $-1.336936
#
#
#                 <td id="T_cb395457_bc78_11e5_aede_80e65010311arow5_col2" class="data row5 col2">
#
#                         $0.562861

# %%
PrettyPandas(df).as_percent(precision=3)
# Out:
#         <style  type="text/css" >
#
#             #T_cb40dfc0_bc78_11e5_ae53_80e65010311a th {
#
#                 background: #eee;
#
#                 font-weight: 500;
#
#             }
#
#             #T_cb40dfc0_bc78_11e5_ae53_80e65010311a td {
#
#                 text-align: right;
#
#                 min-width: 3em;
#
#             }
#
#             #T_cb40dfc0_bc78_11e5_ae53_80e65010311a * {
#
#                 border-color: #c0c0c0;
#
#             }
#
#
#         </style>
#
#         <table id="T_cb40dfc0_bc78_11e5_ae53_80e65010311a" None>
#
#
#         <thead>
#
#             <tr>
#
#                 <th class="blank">
#
#                 <th class="col_heading level0 col0">A
#
#                 <th class="col_heading level0 col1">B
#
#                 <th class="col_heading level0 col2">C
#
#                 <th class="col_heading level0 col3">D
#
#                 <th class="col_heading level0 col4">E
#
#             </tr>
#
#         </thead>
#         <tbody>
#
#             <tr>
#
#                 <th id="T_cb40dfc0_bc78_11e5_ae53_80e65010311a" class="row_heading level4 row0">
#
#                         0.0
#
#
#                 <td id="T_cb40dfc0_bc78_11e5_ae53_80e65010311arow0_col0" class="data row0 col0">
#
#                         100.000%
#
#
#                 <td id="T_cb40dfc0_bc78_11e5_ae53_80e65010311arow0_col1" class="data row0 col1">
#
#                         132.921%
#
#
#                 <td id="T_cb40dfc0_bc78_11e5_ae53_80e65010311arow0_col2" class="data row0 col2">
#
#                         -77.003%
#
#
#                 <td id="T_cb40dfc0_bc78_11e5_ae53_80e65010311arow0_col3" class="data row0 col3">
#
#                         -31.628%
#
#
#                 <td id="T_cb40dfc0_bc78_11e5_ae53_80e65010311arow0_col4" class="data row0 col4">
#
#                         -99.081%
#
#
#             </tr>
#
#             <tr>
#
#                 <th id="T_cb40dfc0_bc78_11e5_ae53_80e65010311a" class="row_heading level4 row1">
#
#                         1.0
#
#
#                 <td id="T_cb40dfc0_bc78_11e5_ae53_80e65010311arow1_col0" class="data row1 col0">
#
#                         200.000%
#
#
#                 <td id="T_cb40dfc0_bc78_11e5_ae53_80e65010311arow1_col1" class="data row1 col1">
#
#                         -107.082%
#
#
#                 <td id="T_cb40dfc0_bc78_11e5_ae53_80e65010311arow1_col2" class="data row1 col2">
#
#                         -143.871%
#
#
#                 <td id="T_cb40dfc0_bc78_11e5_ae53_80e65010311arow1_col3" class="data row1 col3">
#
#                         56.442%
#
#
#                 <td id="T_cb40dfc0_bc78_11e5_ae53_80e65010311arow1_col4" class="data row1 col4">
#
#                         29.572%
#
#
#             </tr>
#
#             <tr>
#
#                 <th id="T_cb40dfc0_bc78_11e5_ae53_80e65010311a" class="row_heading level4 row2">
#
#                         2.0
#
#
#                 <td id="T_cb40dfc0_bc78_11e5_ae53_80e65010311arow2_col0" class="data row2 col0">
#
#                         300.000%
#
#
#                 <td id="T_cb40dfc0_bc78_11e5_ae53_80e65010311arow2_col1" class="data row2 col1">
#
#                         -162.640%
#
#
#                 <td id="T_cb40dfc0_bc78_11e5_ae53_80e65010311arow2_col2" class="data row2 col2">
#
#                         21.957%
#
#
#                 <td id="T_cb40dfc0_bc78_11e5_ae53_80e65010311arow2_col3" class="data row2 col3">
#
#                         67.880%
#
#
#                 <td id="T_cb40dfc0_bc78_11e5_ae53_80e65010311arow2_col4" class="data row2 col4">
#
#                         188.927%
#
#
#             </tr>
#
#             <tr>
#
#                 <th id="T_cb40dfc0_bc78_11e5_ae53_80e65010311a" class="row_heading level4 row3">
#
#                         3.0
#
#
#                 <td id="T_cb40dfc0_bc78_11e5_ae53_80e65010311arow3_col0" class="data row3 col0">
#
#                         400.000%
#
#
#                 <td id="T_cb40dfc0_bc78_11e5_ae53_80e65010311arow3_col1" class="data row3 col1">
#
#                         96.154%
#
#
#                 <td id="T_cb40dfc0_bc78_11e5_ae53_80e65010311arow3_col2" class="data row3 col2">
#
#                         10.401%
#
#
#                 <td id="T_cb40dfc0_bc78_11e5_ae53_80e65010311arow3_col3" class="data row3 col3">
#
#                         -48.117%
#
#
#                 <td id="T_cb40dfc0_bc78_11e5_ae53_80e65010311arow3_col4" class="data row3 col4">
#
#                         85.023%
#
#
#             </tr>
#
#             <tr>
#
#                 <th id="T_cb40dfc0_bc78_11e5_ae53_80e65010311a" class="row_heading level4 row4">
#
#                         4.0
#
#
#                 <td id="T_cb40dfc0_bc78_11e5_ae53_80e65010311arow4_col0" class="data row4 col0">
#
#                         500.000%
#
#
#                 <td id="T_cb40dfc0_bc78_11e5_ae53_80e65010311arow4_col1" class="data row4 col1">
#
#                         145.342%
#
#
#                 <td id="T_cb40dfc0_bc78_11e5_ae53_80e65010311arow4_col2" class="data row4 col2">
#
#                         105.774%
#
#
#                 <td id="T_cb40dfc0_bc78_11e5_ae53_80e65010311arow4_col3" class="data row4 col3">
#
#                         16.556%
#
#
#                 <td id="T_cb40dfc0_bc78_11e5_ae53_80e65010311arow4_col4" class="data row4 col4">
#
#                         51.502%
#
#
#             </tr>
#
#             <tr>
#
#                 <th id="T_cb40dfc0_bc78_11e5_ae53_80e65010311a" class="row_heading level4 row5">
#
#                         5.0
#
#
#                 <td id="T_cb40dfc0_bc78_11e5_ae53_80e65010311arow5_col0" class="data row5 col0">
#
#                         600.000%
#
#
#                 <td id="T_cb40dfc0_bc78_11e5_ae53_80e65010311arow5_col1" class="data row5 col1">
#
#                         -133.694%
#
#
#                 <td id="T_cb40dfc0_bc78_11e5_ae53_80e65010311arow5_col2" class="data row5 col2">
#
#                         56.286%
#
#
#                 <td id="T_cb40dfc0_bc78_1

# %%
PrettyPandas(df).as_money(currency=u"$", precision=3)
# Out:
#         <style  type="text/css" >
#
#             #T_cb45b091_bc78_11e5_be46_80e65010311a th {
#
#                 background: #eee;
#
#                 font-weight: 500;
#
#             }
#
#             #T_cb45b091_bc78_11e5_be46_80e65010311a td {
#
#                 text-align: right;
#
#                 min-width: 3em;
#
#             }
#
#             #T_cb45b091_bc78_11e5_be46_80e65010311a * {
#
#                 border-color: #c0c0c0;
#
#             }
#
#
#         </style>
#
#         <table id="T_cb45b091_bc78_11e5_be46_80e65010311a" None>
#
#
#         <thead>
#
#             <tr>
#
#                 <th class="blank">
#
#                 <th class="col_heading level0 col0">A
#
#                 <th class="col_heading level0 col1">B
#
#                 <th class="col_heading level0 col2">C
#
#                 <th class="col_heading level0 col3">D
#
#                 <th class="col_heading level0 col4">E
#
#             </tr>
#
#         </thead>
#         <tbody>
#
#             <tr>
#
#                 <th id="T_cb45b091_bc78_11e5_be46_80e65010311a" class="row_heading level4 row0">
#
#                         0.0
#
#
#                 <td id="T_cb45b091_bc78_11e5_be46_80e65010311arow0_col0" class="data row0 col0">
#
#                         $1.000
#
#
#                 <td id="T_cb45b091_bc78_11e5_be46_80e65010311arow0_col1" class="data row0 col1">
#
#                         $1.329
#
#
#                 <td id="T_cb45b091_bc78_11e5_be46_80e65010311arow0_col2" class="data row0 col2">
#
#                         $-0.770
#
#
#                 <td id="T_cb45b091_bc78_11e5_be46_80e65010311arow0_col3" class="data row0 col3">
#
#                         $-0.316
#
#
#                 <td id="T_cb45b091_bc78_11e5_be46_80e65010311arow0_col4" class="data row0 col4">
#
#                         $-0.991
#
#
#             </tr>
#
#             <tr>
#
#                 <th id="T_cb45b091_bc78_11e5_be46_80e65010311a" class="row_heading level4 row1">
#
#                         1.0
#
#
#                 <td id="T_cb45b091_bc78_11e5_be46_80e65010311arow1_col0" class="data row1 col0">
#
#                         $2.000
#
#
#                 <td id="T_cb45b091_bc78_11e5_be46_80e65010311arow1_col1" class="data row1 col1">
#
#                         $-1.071
#
#
#                 <td id="T_cb45b091_bc78_11e5_be46_80e65010311arow1_col2" class="data row1 col2">
#
#                         $-1.439
#
#
#                 <td id="T_cb45b091_bc78_11e5_be46_80e65010311arow1_col3" class="data row1 col3">
#
#                         $0.564
#
#
#                 <td id="T_cb45b091_bc78_11e5_be46_80e65010311arow1_col4" class="data row1 col4">
#
#                         $0.296
#
#
#             </tr>
#
#             <tr>
#
#                 <th id="T_cb45b091_bc78_11e5_be46_80e65010311a" class="row_heading level4 row2">
#
#                         2.0
#
#
#                 <td id="T_cb45b091_bc78_11e5_be46_80e65010311arow2_col0" class="data row2 col0">
#
#                         $3.000
#
#
#                 <td id="T_cb45b091_bc78_11e5_be46_80e65010311arow2_col1" class="data row2 col1">
#
#                         $-1.626
#
#
#                 <td id="T_cb45b091_bc78_11e5_be46_80e65010311arow2_col2" class="data row2 col2">
#
#                         $0.220
#
#
#                 <td id="T_cb45b091_bc78_11e5_be46_80e65010311arow2_col3" class="data row2 col3">
#
#                         $0.679
#
#
#                 <td id="T_cb45b091_bc78_11e5_be46_80e65010311arow2_col4" class="data row2 col4">
#
#                         $1.889
#
#
#             </tr>
#
#             <tr>
#
#                 <th id="T_cb45b091_bc78_11e5_be46_80e65010311a" class="row_heading level4 row3">
#
#                         3.0
#
#
#                 <td id="T_cb45b091_bc78_11e5_be46_80e65010311arow3_col0" class="data row3 col0">
#
#                         $4.000
#
#
#                 <td id="T_cb45b091_bc78_11e5_be46_80e65010311arow3_col1" class="data row3 col1">
#
#                         $0.962
#
#
#                 <td id="T_cb45b091_bc78_11e5_be46_80e65010311arow3_col2" class="data row3 col2">
#
#                         $0.104
#
#
#                 <td id="T_cb45b091_bc78_11e5_be46_80e65010311arow3_col3" class="data row3 col3">
#
#                         $-0.481
#
#
#                 <td id="T_cb45b091_bc78_11e5_be46_80e65010311arow3_col4" class="data row3 col4">
#
#                         $0.850
#
#
#             </tr>
#
#             <tr>
#
#                 <th id="T_cb45b091_bc78_11e5_be46_80e65010311a" class="row_heading level4 row4">
#
#                         4.0
#
#
#                 <td id="T_cb45b091_bc78_11e5_be46_80e65010311arow4_col0" class="data row4 col0">
#
#                         $5.000
#
#
#                 <td id="T_cb45b091_bc78_11e5_be46_80e65010311arow4_col1" class="data row4 col1">
#
#                         $1.453
#
#
#                 <td id="T_cb45b091_bc78_11e5_be46_80e65010311arow4_col2" class="data row4 col2">
#
#                         $1.058
#
#
#                 <td id="T_cb45b091_bc78_11e5_be46_80e65010311arow4_col3" class="data row4 col3">
#
#                         $0.166
#
#
#                 <td id="T_cb45b091_bc78_11e5_be46_80e65010311arow4_col4" class="data row4 col4">
#
#                         $0.515
#
#
#             </tr>
#
#             <tr>
#
#                 <th id="T_cb45b091_bc78_11e5_be46_80e65010311a" class="row_heading level4 row5">
#
#                         5.0
#
#
#                 <td id="T_cb45b091_bc78_11e5_be46_80e65010311arow5_col0" class="data row5 col0">
#
#                         $6.000
#
#
#                 <td id="T_cb45b091_bc78_11e5_be46_80e65010311arow5_col1" class="data row5 col1">
#
#                         $-1.337
#
#
#                 <td id="T_cb45b091_bc78_11e5_be46_80e65010311arow5_col2" class="data row5 col2">
#
#                         $0.563
#
#
#                 <td id="T_cb45b091_bc78_11e5_be46_80e65010311arow5_col3" class="dat

# %%
PrettyPandas(df).as_unit('cm', location='suffix')
# Out:
#         <style  type="text/css" >
#
#             #T_cb4af366_bc78_11e5_a8e3_80e65010311a th {
#
#                 background: #eee;
#
#                 font-weight: 500;
#
#             }
#
#             #T_cb4af366_bc78_11e5_a8e3_80e65010311a td {
#
#                 text-align: right;
#
#                 min-width: 3em;
#
#             }
#
#             #T_cb4af366_bc78_11e5_a8e3_80e65010311a * {
#
#                 border-color: #c0c0c0;
#
#             }
#
#
#         </style>
#
#         <table id="T_cb4af366_bc78_11e5_a8e3_80e65010311a" None>
#
#
#         <thead>
#
#             <tr>
#
#                 <th class="blank">
#
#                 <th class="col_heading level0 col0">A
#
#                 <th class="col_heading level0 col1">B
#
#                 <th class="col_heading level0 col2">C
#
#                 <th class="col_heading level0 col3">D
#
#                 <th class="col_heading level0 col4">E
#
#             </tr>
#
#         </thead>
#         <tbody>
#
#             <tr>
#
#                 <th id="T_cb4af366_bc78_11e5_a8e3_80e65010311a" class="row_heading level4 row0">
#
#                         0.0
#
#
#                 <td id="T_cb4af366_bc78_11e5_a8e3_80e65010311arow0_col0" class="data row0 col0">
#
#                         1.000000cm
#
#
#                 <td id="T_cb4af366_bc78_11e5_a8e3_80e65010311arow0_col1" class="data row0 col1">
#
#                         1.329212cm
#
#
#                 <td id="T_cb4af366_bc78_11e5_a8e3_80e65010311arow0_col2" class="data row0 col2">
#
#                         -0.770033cm
#
#
#                 <td id="T_cb4af366_bc78_11e5_a8e3_80e65010311arow0_col3" class="data row0 col3">
#
#                         -0.316280cm
#
#
#                 <td id="T_cb4af366_bc78_11e5_a8e3_80e65010311arow0_col4" class="data row0 col4">
#
#                         -0.990810cm
#
#
#             </tr>
#
#             <tr>
#
#                 <th id="T_cb4af366_bc78_11e5_a8e3_80e65010311a" class="row_heading level4 row1">
#
#                         1.0
#
#
#                 <td id="T_cb4af366_bc78_11e5_a8e3_80e65010311arow1_col0" class="data row1 col0">
#
#                         2.000000cm
#
#
#                 <td id="T_cb4af366_bc78_11e5_a8e3_80e65010311arow1_col1" class="data row1 col1">
#
#                         -1.070816cm
#
#
#                 <td id="T_cb4af366_bc78_11e5_a8e3_80e65010311arow1_col2" class="data row1 col2">
#
#                         -1.438713cm
#
#
#                 <td id="T_cb4af366_bc78_11e5_a8e3_80e65010311arow1_col3" class="data row1 col3">
#
#                         0.564417cm
#
#
#                 <td id="T_cb4af366_bc78_11e5_a8e3_80e65010311arow1_col4" class="data row1 col4">
#
#                         0.295722cm
#
#
#             </tr>
#
#             <tr>
#
#                 <th id="T_cb4af366_bc78_11e5_a8e3_80e65010311a" class="row_heading level4 row2">
#
#                         2.0
#
#
#                 <td id="T_cb4af366_bc78_11e5_a8e3_80e65010311arow2_col0" class="data row2 col0">
#
#                         3.000000cm
#
#
#                 <td id="T_cb4af366_bc78_11e5_a8e3_80e65010311arow2_col1" class="data row2 col1">
#
#                         -1.626404cm
#
#
#                 <td id="T_cb4af366_bc78_11e5_a8e3_80e65010311arow2_col2" class="data row2 col2">
#
#                         0.219565cm
#
#
#                 <td id="T_cb4af366_bc78_11e5_a8e3_80e65010311arow2_col3" class="data row2 col3">
#
#                         0.678805cm
#
#
#                 <td id="T_cb4af366_bc78_11e5_a8e3_80e65010311arow2_col4" class="data row2 col4">
#
#                         1.889273cm
#
#
#             </tr>
#
#             <tr>
#
#                 <th id="T_cb4af366_bc78_11e5_a8e3_80e65010311a" class="row_heading level4 row3">
#
#                         3.0
#
#
#                 <td id="T_cb4af366_bc78_11e5_a8e3_80e65010311arow3_col0" class="data row3 col0">
#
#                         4.000000cm
#
#
#                 <td id="T_cb4af366_bc78_11e5_a8e3_80e65010311arow3_col1" class="data row3 col1">
#
#                         0.961538cm
#
#
#                 <td id="T_cb4af366_bc78_11e5_a8e3_80e65010311arow3_col2" class="data row3 col2">
#
#                         0.104011cm
#
#
#                 <td id="T_cb4af366_bc78_11e5_a8e3_80e65010311arow3_col3" class="data row3 col3">
#
#                         -0.481165cm
#
#
#                 <td id="T_cb4af366_bc78_11e5_a8e3_80e65010311arow3_col4" class="data row3 col4">
#
#                         0.850229cm
#
#
#             </tr>
#
#             <tr>
#
#                 <th id="T_cb4af366_bc78_11e5_a8e3_80e65010311a" class="row_heading level4 row4">
#
#                         4.0
#
#
#                 <td id="T_cb4af366_bc78_11e5_a8e3_80e65010311arow4_col0" class="data row4 col0">
#
#                         5.000000cm
#
#
#                 <td id="T_cb4af366_bc78_11e5_a8e3_80e65010311arow4_col1" class="data row4 col1">
#
#                         1.453425cm
#
#
#                 <td id="T_cb4af366_bc78_11e5_a8e3_80e65010311arow4_col2" class="data row4 col2">
#
#                         1.057737cm
#
#
#                 <td id="T_cb4af366_bc78_11e5_a8e3_80e65010311arow4_col3" class="data row4 col3">
#
#                         0.165562cm
#
#
#                 <td id="T_cb4af366_bc78_11e5_a8e3_80e65010311arow4_col4" class="data row4 col4">
#
#                         0.515018cm
#
#
#             </tr>
#
#             <tr>
#
#                 <th id="T_cb4af366_bc78_11e5_a8e3_80e65010311a" class="row_heading level4 row5">
#
#                         5.0
#
#
#                 <td id="T_cb4af366_bc78_11e5_a8e3_80e65010311arow5_col0" class="data row5 col0">
#
#                         6.000000cm
#
#
#                 <td id="T_cb4af366_bc78_11e5_a8e3_80e65010311arow5_col1" class="data row5 col1">
#
#                         -1.336936cm
#
#
#                 <td id="T_cb4af366_bc78_11e5_a8e3_80e65010311arow5_col2" class="data row5 col2">
#
#                         0.562861cm

# %%
PrettyPandas(df).as_percent(subset=['B'])
# Out:
#         <style  type="text/css" >
#
#             #T_cb4f1ba8_bc78_11e5_8e7c_80e65010311a th {
#
#                 background: #eee;
#
#                 font-weight: 500;
#
#             }
#
#             #T_cb4f1ba8_bc78_11e5_8e7c_80e65010311a td {
#
#                 text-align: right;
#
#                 min-width: 3em;
#
#             }
#
#             #T_cb4f1ba8_bc78_11e5_8e7c_80e65010311a * {
#
#                 border-color: #c0c0c0;
#
#             }
#
#
#         </style>
#
#         <table id="T_cb4f1ba8_bc78_11e5_8e7c_80e65010311a" None>
#
#
#         <thead>
#
#             <tr>
#
#                 <th class="blank">
#
#                 <th class="col_heading level0 col0">A
#
#                 <th class="col_heading level0 col1">B
#
#                 <th class="col_heading level0 col2">C
#
#                 <th class="col_heading level0 col3">D
#
#                 <th class="col_heading level0 col4">E
#
#             </tr>
#
#         </thead>
#         <tbody>
#
#             <tr>
#
#                 <th id="T_cb4f1ba8_bc78_11e5_8e7c_80e65010311a" class="row_heading level4 row0">
#
#                         0.0
#
#
#                 <td id="T_cb4f1ba8_bc78_11e5_8e7c_80e65010311arow0_col0" class="data row0 col0">
#
#                         1.0
#
#
#                 <td id="T_cb4f1ba8_bc78_11e5_8e7c_80e65010311arow0_col1" class="data row0 col1">
#
#                         132.921217%
#
#
#                 <td id="T_cb4f1ba8_bc78_11e5_8e7c_80e65010311arow0_col2" class="data row0 col2">
#
#                         -0.770033
#
#
#                 <td id="T_cb4f1ba8_bc78_11e5_8e7c_80e65010311arow0_col3" class="data row0 col3">
#
#                         -0.31628
#
#
#                 <td id="T_cb4f1ba8_bc78_11e5_8e7c_80e65010311arow0_col4" class="data row0 col4">
#
#                         -0.99081
#
#
#             </tr>
#
#             <tr>
#
#                 <th id="T_cb4f1ba8_bc78_11e5_8e7c_80e65010311a" class="row_heading level4 row1">
#
#                         1.0
#
#
#                 <td id="T_cb4f1ba8_bc78_11e5_8e7c_80e65010311arow1_col0" class="data row1 col0">
#
#                         2.0
#
#
#                 <td id="T_cb4f1ba8_bc78_11e5_8e7c_80e65010311arow1_col1" class="data row1 col1">
#
#                         -107.081626%
#
#
#                 <td id="T_cb4f1ba8_bc78_11e5_8e7c_80e65010311arow1_col2" class="data row1 col2">
#
#                         -1.438713
#
#
#                 <td id="T_cb4f1ba8_bc78_11e5_8e7c_80e65010311arow1_col3" class="data row1 col3">
#
#                         0.564417
#
#
#                 <td id="T_cb4f1ba8_bc78_11e5_8e7c_80e65010311arow1_col4" class="data row1 col4">
#
#                         0.295722
#
#
#             </tr>
#
#             <tr>
#
#                 <th id="T_cb4f1ba8_bc78_11e5_8e7c_80e65010311a" class="row_heading level4 row2">
#
#                         2.0
#
#
#                 <td id="T_cb4f1ba8_bc78_11e5_8e7c_80e65010311arow2_col0" class="data row2 col0">
#
#                         3.0
#
#
#                 <td id="T_cb4f1ba8_bc78_11e5_8e7c_80e65010311arow2_col1" class="data row2 col1">
#
#                         -162.640423%
#
#
#                 <td id="T_cb4f1ba8_bc78_11e5_8e7c_80e65010311arow2_col2" class="data row2 col2">
#
#                         0.219565
#
#
#                 <td id="T_cb4f1ba8_bc78_11e5_8e7c_80e65010311arow2_col3" class="data row2 col3">
#
#                         0.678805
#
#
#                 <td id="T_cb4f1ba8_bc78_11e5_8e7c_80e65010311arow2_col4" class="data row2 col4">
#
#                         1.889273
#
#
#             </tr>
#
#             <tr>
#
#                 <th id="T_cb4f1ba8_bc78_11e5_8e7c_80e65010311a" class="row_heading level4 row3">
#
#                         3.0
#
#
#                 <td id="T_cb4f1ba8_bc78_11e5_8e7c_80e65010311arow3_col0" class="data row3 col0">
#
#                         4.0
#
#
#                 <td id="T_cb4f1ba8_bc78_11e5_8e7c_80e65010311arow3_col1" class="data row3 col1">
#
#                         96.153840%
#
#
#                 <td id="T_cb4f1ba8_bc78_11e5_8e7c_80e65010311arow3_col2" class="data row3 col2">
#
#                         0.104011
#
#
#                 <td id="T_cb4f1ba8_bc78_11e5_8e7c_80e65010311arow3_col3" class="data row3 col3">
#
#                         -0.481165
#
#
#                 <td id="T_cb4f1ba8_bc78_11e5_8e7c_80e65010311arow3_col4" class="data row3 col4">
#
#                         0.850229
#
#
#             </tr>
#
#             <tr>
#
#                 <th id="T_cb4f1ba8_bc78_11e5_8e7c_80e65010311a" class="row_heading level4 row4">
#
#                         4.0
#
#
#                 <td id="T_cb4f1ba8_bc78_11e5_8e7c_80e65010311arow4_col0" class="data row4 col0">
#
#                         5.0
#
#
#                 <td id="T_cb4f1ba8_bc78_11e5_8e7c_80e65010311arow4_col1" class="data row4 col1">
#
#                         145.342467%
#
#
#                 <td id="T_cb4f1ba8_bc78_11e5_8e7c_80e65010311arow4_col2" class="data row4 col2">
#
#                         1.057737
#
#
#                 <td id="T_cb4f1ba8_bc78_11e5_8e7c_80e65010311arow4_col3" class="data row4 col3">
#
#                         0.165562
#
#
#                 <td id="T_cb4f1ba8_bc78_11e5_8e7c_80e65010311arow4_col4" class="data row4 col4">
#
#                         0.515018
#
#
#             </tr>
#
#             <tr>
#
#                 <th id="T_cb4f1ba8_bc78_11e5_8e7c_80e65010311a" class="row_heading level4 row5">
#
#                         5.0
#
#
#                 <td id="T_cb4f1ba8_bc78_11e5_8e7c_80e65010311arow5_col0" class="data row5 col0">
#
#                         6.0
#
#
#                 <td id="T_cb4f1ba8_bc78_11e5_8e7c_80e65010311arow5_col1" class="data row5 col1">
#
#                         -133.693569%
#
#
#                 <td id="T_cb4f1ba8_bc78_11e5_8e7c_80e65010311arow5_col2" class="data row5 col2">
#
#                         0.562861
#
#
#                 <td id="T_cb4f1ba8_bc78_11

# %%
PrettyPandas(df).as_percent(subset=['B']).total()
# Out:
#         <style  type="text/css" >
#
#             #T_cb539097_bc78_11e5_896c_80e65010311a th {
#
#                 background: #eee;
#
#                 font-weight: 500;
#
#             }
#
#             #T_cb539097_bc78_11e5_896c_80e65010311a td {
#
#                 text-align: right;
#
#                 min-width: 3em;
#
#             }
#
#             #T_cb539097_bc78_11e5_896c_80e65010311a * {
#
#                 border-color: #c0c0c0;
#
#             }
#
#             #T_cb539097_bc78_11e5_896c_80e65010311a tr:nth-child(11) {
#
#                 background: #eee;
#
#                 font-weight: 500;
#
#             }
#
#
#         </style>
#
#         <table id="T_cb539097_bc78_11e5_896c_80e65010311a" None>
#
#
#         <thead>
#
#             <tr>
#
#                 <th class="blank">
#
#                 <th class="col_heading level0 col0">A
#
#                 <th class="col_heading level0 col1">B
#
#                 <th class="col_heading level0 col2">C
#
#                 <th class="col_heading level0 col3">D
#
#                 <th class="col_heading level0 col4">E
#
#             </tr>
#
#         </thead>
#         <tbody>
#
#             <tr>
#
#                 <th id="T_cb539097_bc78_11e5_896c_80e65010311a" class="row_heading level4 row0">
#
#                         0.0
#
#
#                 <td id="T_cb539097_bc78_11e5_896c_80e65010311arow0_col0" class="data row0 col0">
#
#                         1.0
#
#
#                 <td id="T_cb539097_bc78_11e5_896c_80e65010311arow0_col1" class="data row0 col1">
#
#                         132.921217%
#
#
#                 <td id="T_cb539097_bc78_11e5_896c_80e65010311arow0_col2" class="data row0 col2">
#
#                         -0.770033
#
#
#                 <td id="T_cb539097_bc78_11e5_896c_80e65010311arow0_col3" class="data row0 col3">
#
#                         -0.31628
#
#
#                 <td id="T_cb539097_bc78_11e5_896c_80e65010311arow0_col4" class="data row0 col4">
#
#                         -0.99081
#
#
#             </tr>
#
#             <tr>
#
#                 <th id="T_cb539097_bc78_11e5_896c_80e65010311a" class="row_heading level4 row1">
#
#                         1.0
#
#
#                 <td id="T_cb539097_bc78_11e5_896c_80e65010311arow1_col0" class="data row1 col0">
#
#                         2.0
#
#
#                 <td id="T_cb539097_bc78_11e5_896c_80e65010311arow1_col1" class="data row1 col1">
#
#                         -107.081626%
#
#
#                 <td id="T_cb539097_bc78_11e5_896c_80e65010311arow1_col2" class="data row1 col2">
#
#                         -1.438713
#
#
#                 <td id="T_cb539097_bc78_11e5_896c_80e65010311arow1_col3" class="data row1 col3">
#
#                         0.564417
#
#
#                 <td id="T_cb539097_bc78_11e5_896c_80e65010311arow1_col4" class="data row1 col4">
#
#                         0.295722
#
#
#             </tr>
#
#             <tr>
#
#                 <th id="T_cb539097_bc78_11e5_896c_80e65010311a" class="row_heading level4 row2">
#
#                         2.0
#
#
#                 <td id="T_cb539097_bc78_11e5_896c_80e65010311arow2_col0" class="data row2 col0">
#
#                         3.0
#
#
#                 <td id="T_cb539097_bc78_11e5_896c_80e65010311arow2_col1" class="data row2 col1">
#
#                         -162.640423%
#
#
#                 <td id="T_cb539097_bc78_11e5_896c_80e65010311arow2_col2" class="data row2 col2">
#
#                         0.219565
#
#
#                 <td id="T_cb539097_bc78_11e5_896c_80e65010311arow2_col3" class="data row2 col3">
#
#                         0.678805
#
#
#                 <td id="T_cb539097_bc78_11e5_896c_80e65010311arow2_col4" class="data row2 col4">
#
#                         1.889273
#
#
#             </tr>
#
#             <tr>
#
#                 <th id="T_cb539097_bc78_11e5_896c_80e65010311a" class="row_heading level4 row3">
#
#                         3.0
#
#
#                 <td id="T_cb539097_bc78_11e5_896c_80e65010311arow3_col0" class="data row3 col0">
#
#                         4.0
#
#
#                 <td id="T_cb539097_bc78_11e5_896c_80e65010311arow3_col1" class="data row3 col1">
#
#                         96.153840%
#
#
#                 <td id="T_cb539097_bc78_11e5_896c_80e65010311arow3_col2" class="data row3 col2">
#
#                         0.104011
#
#
#                 <td id="T_cb539097_bc78_11e5_896c_80e65010311arow3_col3" class="data row3 col3">
#
#                         -0.481165
#
#
#                 <td id="T_cb539097_bc78_11e5_896c_80e65010311arow3_col4" class="data row3 col4">
#
#                         0.850229
#
#
#             </tr>
#
#             <tr>
#
#                 <th id="T_cb539097_bc78_11e5_896c_80e65010311a" class="row_heading level4 row4">
#
#                         4.0
#
#
#                 <td id="T_cb539097_bc78_11e5_896c_80e65010311arow4_col0" class="data row4 col0">
#
#                         5.0
#
#
#                 <td id="T_cb539097_bc78_11e5_896c_80e65010311arow4_col1" class="data row4 col1">
#
#                         145.342467%
#
#
#                 <td id="T_cb539097_bc78_11e5_896c_80e65010311arow4_col2" class="data row4 col2">
#
#                         1.057737
#
#
#                 <td id="T_cb539097_bc78_11e5_896c_80e65010311arow4_col3" class="data row4 col3">
#
#                         0.165562
#
#
#                 <td id="T_cb539097_bc78_11e5_896c_80e65010311arow4_col4" class="data row4 col4">
#
#                         0.515018
#
#
#             </tr>
#
#             <tr>
#
#                 <th id="T_cb539097_bc78_11e5_896c_80e65010311a" class="row_heading level4 row5">
#
#                         5.0
#
#
#                 <td id="T_cb539097_bc78_11e5_896c_80e65010311arow5_col0" class="data row5 col0">
#
#                         6.0
#
#
#                 <td id="T_cb539097_bc78_11e5_896c_80e65010311arow5_col1" class="data row5 col1">
#
#                         -133.693569%
#
#
#                 <td id="T_cb53
